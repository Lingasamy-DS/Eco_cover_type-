# %% [markdown]
# <a href="https://colab.research.google.com/github/Lingasamy-DS/Eco_cover_type-/blob/main/1_Data_Cleaning_Eco_Cover_Type_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing the necessry libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read The Data Using Pandas**

# %%
data = pd.read_csv("/content/drive/MyDrive/Eco forest projects/cover_type (1).csv")
data.head()
# Out:
#    Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 0       2596      51      3                               258
# 1       2590      56      2                               212
# 2       2804     139      9                               268
# 3       2785     155     18                               242
# 4       2595      45      2                               153
#
#    Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 0                               0                              510
# 1                              -6                              390
# 2                              65                             3180
# 3                             118                             3090
# 4                              -1                              391
#
#    Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 0            221             232            148
# 1            220             235            151
# ...

# %%
data.tail()
# Out:
#         Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 145885       2834      88      8                               376
# 145886       2832      68      4                               390
# 145887       2829      80      7                               390
# 145888       2826     121      7                               379
# 145889       2823     132     12                               371
#
#         Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 145885                              44                             2552
# 145886                              44                             2522
# 145887                              33                             2492
# 145888                              30                             2462
# 145889                              27                             2432
#
#         Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 145885            232             227            128
# ...

# %% [markdown]
# **Understanding the dataset**

# %%
print(f"1.shape of the dataset: {data.shape}")
print("\n")
print(f"2.coulmns of the dataset: \n {data.columns}")
print("\n")
print(f"3.number of duplicates row: {data.duplicated().sum()}")
print("\n")
print(f"4.number of null values: \n {data.isnull().sum()}")
print("\n")

for col in data.columns:
  print(f"{col}:\n Unique values:",data[col].nunique(),"\n", data[col].unique())
  print()
  print()
# Out:
# 1.shape of the dataset: (145890, 13)
#
#
# 2.coulmns of the dataset:
#  Index(['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
#        'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
#        'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points', 'Cover_Type', 'Wilderness_Area',
#        'Soil_Type'],
#       dtype='object')
#
#
# 3.number of duplicates row: 0
#
#
# 4.number of null values:
#  Elevation                             0
# Aspect                                0
# Slope                                 0
# Horizontal_Distance_To_Hydrology      0
# Vertical_Distance_To_Hydrology        0
# Horizontal_Distance_To_Roadways       0
# Hillshade_9am                         0
# Hillshade_Noon                        0
# Hillshade_3pm                         0
# Horizontal_Distance_To_Fire_Points    0
# Cover_Type                            0
# Wilderness_Area                       0
# ...

# %% [markdown]
# **Dataset features and its Datatypes**

# %%
print(f"Data Types of the features: \n {data.dtypes}")
print()
data.info()
print()
# Removed data.value_counts as it was not called and not used directly for plotting
# Corrected the barplot call to use sns.countplot for visualizing counts of Cover_Type
sns.countplot(x=data["Cover_Type"])
plt.title("Distribution of Cover_Type")
plt.xticks(rotation=45)
plt.show()
# Out:
# Data Types of the features:
#  Elevation                              int64
# Aspect                                 int64
# Slope                                  int64
# Horizontal_Distance_To_Hydrology       int64
# Vertical_Distance_To_Hydrology         int64
# Horizontal_Distance_To_Roadways        int64
# Hillshade_9am                          int64
# Hillshade_Noon                         int64
# Hillshade_3pm                          int64
# Horizontal_Distance_To_Fire_Points     int64
# Cover_Type                            object
# Wilderness_Area                        int64
# Soil_Type                              int64
# dtype: object
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145890 entries, 0 to 145889
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Elevation                           145890 non-null  int64
# ...

# %% [markdown]
# Note : Observed in given dataset there is no null values, duplicate values and the no date time formats so no nned to do the datahandling work.

# %%
data.describe()
# Out:
#            Elevation         Aspect          Slope  \
# count  145890.000000  145890.000000  145890.000000
# mean     2874.458949     141.127418      11.925574
# std       210.801279     107.719296       6.319326
# min      1863.000000       0.000000       0.000000
# 25%      2747.000000      54.000000       7.000000
# 50%      2909.000000     108.000000      11.000000
# 75%      3004.000000     217.000000      15.000000
# max      3849.000000     360.000000      61.000000
#
#        Horizontal_Distance_To_Hydrology  Vertical_Distance_To_Hydrology  \
# count                     145890.000000                   145890.000000
# mean                         251.824738                       34.554322
# std                          192.473899                       41.215776
# min                            0.000000                     -146.000000
# 25%                           95.000000                        7.000000
# ...

# %%
plt.boxplot(data["Slope"])
plt.show()

# %%
sns.barplot(x = data["Cover_Type"], y = data["Horizontal_Distance_To_Roadways"])
plt.title("Bar plots Between Cover_Type & orizontal_Ditance_To_roadways")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# From above bar chart we can understood that horizontal distance to roadways to classify the some types of the forest cover

# %%
data_col = data.select_dtypes(exclude=['object'])
data_col.corr()
# Out:
#                                     Elevation    Aspect     Slope  \
# Elevation                            1.000000  0.017768 -0.155170
# Aspect                               0.017768  1.000000  0.071880
# Slope                               -0.155170  0.071880  1.000000
# Horizontal_Distance_To_Hydrology     0.357278  0.011966 -0.115367
# Vertical_Distance_To_Hydrology       0.154614  0.090323  0.223258
# Horizontal_Distance_To_Roadways      0.678938  0.114545 -0.069879
# Hillshade_9am                        0.018902 -0.556815 -0.212730
# Hillshade_Noon                       0.151631  0.329254 -0.571765
# Hillshade_3pm                        0.094942  0.617892 -0.278075
# Horizontal_Distance_To_Fire_Points   0.198058 -0.052874 -0.198201
# Wilderness_Area                     -0.384601  0.063850  0.263769
# Soil_Type                            0.510632  0.071205  0.146744
#
#                                     Horizontal_Distance_To_Hydrology  \
# ...

# %% [markdown]
# **Outlier checking**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
#        'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
#        'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points']

# %%
numerical_cols = ['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
       'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
       'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
       'Horizontal_Distance_To_Fire_Points']
# Loop through numerical columns and create boxplots

plt.figure(figsize=(15, 7))
plt.suptitle("Boxplots before Outliers removal")
for i in range(0, len(numerical_cols)):
    plt.subplot(2, 5, i+1)
    sns.boxplot(y=data[numerical_cols[i]],color='purple')
    plt.tight_layout()

# %% [markdown]
# **Clearing the outliers by the IQR method**

# %%
for col in numerical_cols:
  Q1 = data[col].quantile(0.25)
  Q3 = data[col].quantile(0.75)
  IQR = Q3-Q1

  upper_bound = Q3 +1.5 * IQR
  lower_bound = Q1 - 1.5 * IQR

  # correct the ouliers by cap the upper and lower bound

  data[col] = np.where(data[col]>upper_bound, upper_bound, data[col])
  data[col] = np.where(data[col]<lower_bound, lower_bound,data[col])

# %%
plt.figure(figsize=(15,7))
for i in range(0, len(numerical_cols)):
  plt.subplot(2,5,i+1)
  sns.boxplot(y = data[numerical_cols[i]], color = "green")
  plt.tight_layout()
  #plt.show()

# %% [markdown]
# Now there is no outlier in the data and going to save in the following file path

# %%
data.to_csv("/content/drive/MyDrive/Eco_Forest_Cover_Type_21.06.26/data_new.csv", index = False)

# %%
data.columns
# Out:
# Index(['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
#        'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
#        'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points', 'Cover_Type', 'Wilderness_Area',
#        'Soil_Type'],
#       dtype='object')

# %%
def boxplot(x,y):
 sns.boxplot(x = x, y = y, data=data)
 plt.xticks(rotation=45)
 plt.show()

# %%
x= 'Cover_Type'
y = 'Elevation'
boxplot(x,y)
